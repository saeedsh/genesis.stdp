# %%
import numpy as np
import pylab
doc = np.loadtxt('output.log')
doc2 = np.loadtxt('output2.log')

a=[]
b=[]
c=[]

a2=[]
b2=[]
c2=[]

for x in doc:
    a.append(x[0])
    b.append(x[1])
    c.append(x[2])

for x in doc2:
    a2.append(x[0])
    b2.append(x[1])
    c2.append(x[2])

pylab.plot(a,b)
pylab.plot(a2,b2)

pylab.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-16c41a5188f0> in <module>()
#      22     c2.append(x[2])
#      23
# ---> 24 b=b+1
#      25 pylab.plot(a,b)
#      26 pylab.plot(a2,b2)
#
# TypeError: can only concatenate list (not "int") to list

# %%
# Out:
# [249376.49600000001,
#  2675748.0299999998,
#  4983783.7800000003,
#  7179255.0700000003,
#  9267651.7400000002,
#  11254195.9,
#  13143855.0,
#  14941354.1,
#  16651187.9,
#  18277632.0,
#  19824753.300000001,
#  21296420.5,
#  22696313.5,
#  24027932.699999999,
#  25294608.0,
#  26499506.699999999,
#  27645641.600000001,
#  28735878.800000001,
#  29772944.300000001,
#  30759431.5,
#  31697807.0,
#  32590417.399999999,
#  33439494.5,
#  34247161.5,
#  35015438.100000001,
#  35746245.299999997,
#  36441410.5,
#  37102672.100000001,
#  37731683.5,
#  38330017.600000001,
#  38899170.5,
#  39440565.5,
#  39955556.200000003,
#  40445430.5,
#  40911413.399999999,
#  41354669.899999999,
#  41776308.5,
#  42177383.399999999,
#  42558897.700000003,
#  42921805.299999997,
#  43267013.700000003,
#  43595386.0,
#  43907743.299999997,
#  44204866.799999997,
#  44487499.299999997,
#  44756347.700000003,
#  45012084.200000003,
#  45255348.200000003,
#  45486748.100000001,
#  45706862.399999999,
# ...
